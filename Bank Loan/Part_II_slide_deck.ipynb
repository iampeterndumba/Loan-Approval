# %% [markdown]
# # Part II - Loan Approval
# ## by Peter

# %% [markdown]
# ## Investigation Overview
# This project aim is to investigate the creteria for loan approval, thus the overall goal is to determine the key features or factors contributing to loan approval or a loan application to be rejected.
# ## Dataset Overview
# The dataset is from Prosper Market In, US based company that specialised in loan and my task in this project was to analyse the data with hope to find patterns that exist.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
loan_df=pd.read_csv("prosperLoanData.csv")

# %% [markdown]
# ## #1 Visual
# As per analysis, it is found that many times loan is given to working class. The visual below illustrate that borrowers are employed are on high count of receiving loan as compared to self employed or the unemployed individuals.

# %%
color_base=sb.color_palette()[0]
fig=plt.figure(figsize=(9,6))
sb.countplot(data=loan_df, x="EmploymentStatus",color=color_base)
plt.xlabel("Employment Status")
plt.ylabel("Count ")
plt.title("Employment Status of Borrower vs Counts")
# Out:
# Text(0.5, 1.0, 'Employment Status of Borrower vs Counts')

# %% [markdown]
# ## #2 Visual
# Through my analysis ,I also found that having high income has an impact to the loan approval. It appears as below graph that individuals with earning has a chance of receiving the loan,and also majority of people who receives the loan are those who earn less than 50k but not including  > 24K

# %%
fig_size = plt.figure()
fig_size.set_figwidth(14)
fig_size.set_figheight(6)
plt.hist(data=loan_df,x="IncomeRange",bins=15)
plt.xlabel("Income range")
plt.ylabel("Counts")
plt.title("Income Range vs Counts")
# Out:
# Text(0.5, 1.0, 'Income Range vs Counts')

# %% [markdown]
# ## #3 Visual
# Using scattter plot to find the relationship, I didnot find the relationship between income range and Loan Origninal

# %%
plt.figure(figsize=(12,8))
plt.scatter(data=loan_df,x="IncomeRange",y="LoanOriginalAmount")

# %%
# !jupyter nbconvert Part_II_slide_deck.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck.ipynb to slides
# [NbConvertApp] Writing 622598 bytes to Part_II_slide_deck.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\Users\Peter\anaconda3\PeterAnaconda3\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\Peter\anaconda3\PeterAnaconda3\lib\site-packages\jupyter_core\application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\Peter\anaconda3\PeterAnaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Peter\anaconda3\PeterAnaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 346, in start
#     self.convert_notebooks()
# ...
